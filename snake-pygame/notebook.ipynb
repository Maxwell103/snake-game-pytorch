# %% [markdown]
# https://www.youtube.com/watch?v=L8ypSXwyBds

# %% [markdown]
# conda create -n pygame_env python=3.7

# %% [markdown]
# conda activate pygame_env

# %% [markdown]
# python "C:\Users\maxwe\Documents\Github repos\snake-game-pytorch\snake-pygame\agent.py"

# %% [markdown]
# pip install pygame
# pip install
# pip3 install torch torchvision

# %% [markdown]
# ## Reward
#
# - eat food : +10
# - game over: -10
# - else: 0

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import sys

# Print the list of directories in sys.path
print(sys.path)
# Out:
# ['c:\\Users\\maxwe\\Documents\\Github repos\\snake-game-pytorch\\snake-pygame', 'c:\\Users\\maxwe\\anaconda3\\python39.zip', 'c:\\Users\\maxwe\\anaconda3\\DLLs', 'c:\\Users\\maxwe\\anaconda3\\lib', 'c:\\Users\\maxwe\\anaconda3', '', 'c:\\Users\\maxwe\\anaconda3\\lib\\site-packages', 'c:\\Users\\maxwe\\anaconda3\\lib\\site-packages\\win32', 'c:\\Users\\maxwe\\anaconda3\\lib\\site-packages\\win32\\lib', 'c:\\Users\\maxwe\\anaconda3\\lib\\site-packages\\Pythonwin', 'c:\\Users\\maxwe\\anaconda3\\lib\\site-packages\\IPython\\extensions', 'C:\\Users\\maxwe\\.ipython']

# %%
sys.path

# %%
import sys

# Append directory path to sys.path
sys.path.append(r'C:\Users\maxwe\Documents\Github repos\snake-game-pytorch\snake-pygame')
